# %%
from google.colab import drive
#This imports the drive module from the google.colab package, which is a set of tools specifically created for working with Google Colab.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""
This command mounts your Google Drive to a specific directory in the Colab environment, which in this case is /content/drive.
When this is executed:

Colab will prompt you to authenticate by asking for access to your Google account.
Once you grant access, your Google Drive will be "mounted," meaning it will be accessible like a local file system.
You can now browse, read, or write files in the /content/drive directory as if they were stored locally on Colab."""
# Out:
# '\nThis command mounts your Google Drive to a specific directory in the Colab environment, which in this case is /content/drive.\nWhen this is executed:\n\nColab will prompt you to authenticate by asking for access to your Google account.\nOnce you grant access, your Google Drive will be "mounted," meaning it will be accessible like a local file system.\nYou can now browse, read, or write files in the /content/drive directory as if they were stored locally on Colab.'

# %%
# importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing as per

# %%
#importing datasets
data1= pd.read_csv('/content/drive/MyDrive/ dataset/House Price India.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data1
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
data = data1.drop(columns=['id','Date','Postal Code'])

# %%
data
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                 2.50         3650      9050
# 1                       4                 2.50         2920      4000
# 2                       5                 2.75         2910      9480
# 3                       4                 2.50         3310     42998
# 4                       3                 2.00         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                 1.50         1556     20000
# 14616                   3                 2.00         1680      7000
# 14617                   2                 1.00         1070      6120
# 14618                   4                 1.00         1030      6621
# 14619                   3                 1.00          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                   2.0                   0                4
# ...

# %%
# importing the modules
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
hm = sn.heatmap(data = data)

# %%
data
#Day to Flowering (DFF),
#Plant Height (PH in cm),
#Fruit Diameter (FD),
#Fruit Length (FL),
#Fruit Weight (FW),
#Normalized Difference Vegetation Index(NDVI),
#Specific Leaf Area (SLA in cm2),
#Soil plant analysis
#development (SPAD),
#Total Fruit Number (TF), and
#Yield per Plant (YPP in kg)."""
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                 2.50         3650      9050
# 1                       4                 2.50         2920      4000
# 2                       5                 2.75         2910      9480
# 3                       4                 2.50         3310     42998
# 4                       3                 2.00         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                 1.50         1556     20000
# 14616                   3                 2.00         1680      7000
# 14617                   2                 1.00         1070      6120
# 14618                   4                 1.00         1030      6621
# 14619                   3                 1.00          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                   2.0                   0                4
# ...

# %%
x1 = data.drop(columns=['Price'])

# %%
x1
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                 2.50         3650      9050
# 1                       4                 2.50         2920      4000
# 2                       5                 2.75         2910      9480
# 3                       4                 2.50         3310     42998
# 4                       3                 2.00         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                 1.50         1556     20000
# 14616                   3                 2.00         1680      7000
# 14617                   2                 1.00         1070      6120
# 14618                   4                 1.00         1030      6621
# 14619                   3                 1.00          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                   2.0                   0                4
# ...

# %%
y1 = data['Price']

# %%
y1
# Out:
# 0        2380000
# 1        1400000
# 2        1200000
# 3         838000
# 4         805000
#           ...
# 14615     221700
# 14616     219200
# 14617     209000
# 14618     205000
# 14619     146000
# Name: Price, Length: 14620, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size= 0.20, random_state=1)

# %%
"""
1. from sklearn.model_selection import train_test_split:
This imports the train_test_split function from the sklearn.model_selection module, which is part of the scikit-learn library. This function helps in splitting your dataset into training and testing subsets.

2. The train_test_split function:
The function is used to split arrays or matrices into random training and testing subsets. The syntax:

python
Copy code
train_test_split(inputs, targets, test_size=..., random_state=...)
x1: This is your feature data (input variables or independent variables).
y1: This is your target data (labels or dependent variables).
test_size=0.20: Specifies the proportion of the dataset to be included in the test set. In this case, 20% of the data will be used for testing, and 80% for training.
random_state=1: Ensures that the split is reproducible. The same data will be split in the same way if this code is run again with the same random_state value.
3. The Output Variables:
The function returns four arrays:

python
Copy code
x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size= 0.20, random_state=1)
x_train1: Contains 80% of the feature data, used for training the model.
x_test1: Contains 20% of the feature data, used for testing the model’s performance.
y_train1: Contains the corresponding 80% of the target data (labels), used to train the model.
y_test1: Contains the corresponding 20% of the target data (labels), used to evaluate the model on unseen data.
Example:
If you have a dataset with 1000 rows, and you run this code with test_size=0.20, the dataset will be split into:

800 rows in x_train1 and y_train1 (for training),
200 rows in x_test1 and y_test1 (for testing).
This way, the model can be trained on x_train1 and evaluated on x_test1 to check how well it generalizes to new data."""
# Out:
# '\n1. from sklearn.model_selection import train_test_split:\nThis imports the train_test_split function from the sklearn.model_selection module, which is part of the scikit-learn library. This function helps in splitting your dataset into training and testing subsets.\n\n2. The train_test_split function:\nThe function is used to split arrays or matrices into random training and testing subsets. The syntax:\n\npython\nCopy code\ntrain_test_split(inputs, targets, test_size=..., random_state=...)\nx1: This is your feature data (input variables or independent variables).\ny1: This is your target data (labels or dependent variables).\ntest_size=0.20: Specifies the proportion of the dataset to be included in the test set. In this case, 20% of the data will be used for testing, and 80% for training.\nrandom_state=1: Ensures that the split is reproducible. The same data will be split in the same way if this code is run again with the same random_state value.\n3. The Output Variables:\nThe fu
# ...

# %%
x_test1
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 12478                   5                 2.50         1710      7700
# 10831                   4                 3.50         4010      9654
# 153                     2                 1.00         1200      8063
# 6008                    4                 1.75         2600     41041
# 10550                   3                 1.75         1250     17493
# ...                   ...                  ...          ...       ...
# 5518                    3                 2.00         1420      1369
# 3709                    3                 1.50         2450     12497
# 7627                    3                 3.00         3920     13085
# 561                     3                 1.00         1280      9898
# 3991                    3                 2.50         2200     11000
#
#        number of floors  waterfront present  number of views  \
# 12478               1.5                   0                0
# ...

# %%
y_test1.to_csv('/content/sample_data/.csv')

# %%
pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 9.1 MB/s eta 0:00:00
# ...

# %%
from sklearn.datasets import load_diabetes
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import VotingRegressor
#from catboost import CatBoostRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn import linear_model


#Linear Regression
from sklearn.linear_model import LinearRegression
#regressor = LinearRegression()

#Stochastic Gradient Descent Regression (rejected)
from sklearn.linear_model import SGDRegressor
#regressor = SGDRegressor()

#Best hyperparameters : {'learning_rate': 0.0398116285815693, 'max_depth': 7, 'subsample': 0.9527371820966462, 'colsample_bytree': 0.5319119933474897, 'min_child_weight': 3}
#XGBoost Regressor
from xgboost.sklearn import XGBRegressor
#regressor = XGBRegressor(learning_rate= 0.0398116285815693, max_depth= 7, subsample= 0.9527371820966462, colsample_bytree= 0.5319119933474897, min_child_weight= 3)

#LGBM Regressor
from lightgbm import LGBMRegressor
#regressor = LGBMRegressor()

#CatBoost Regressor
#from catboost import CatBoostRegressor
#regressor = CatBoostRegressor()

#Kernel Ridge Regression
from sklearn.kernel_ridge import KernelRidge
#regressor = KernelRidge()

#Elastic Net Regression
from sklearn.linear_model import ElasticNet
#regressor = ElasticNet()

#Bayesian Ridge Regression
from sklearn.linear_model import BayesianRidge
#regressor = BayesianRidge()

#Gradient Boosting Regression
from sklearn.ensemble import GradientBoostingRegressor
#regressor = GradientBoostingRegressor()

#Support Vector Machine (rejected)
from sklearn.svm import SVR
#regressor = SVR()
from sklearn.ensemble import HistGradientBoostingRegressor
#regressor = HistGradientBoostingRegressor()

from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
#regressor = RandomForestRegressor()

# %%
# Train the model using training data
regressor.fit(x_train1, y_train1)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.5319119933474897, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.0398116285815693, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Now the model is trained and can be used for making predictions
predicted_label = regressor.predict(x_test1)

# %%
predicted_label
# Out:
# array([ 453226.8 , 1446070.1 ,  218056.34, ..., 2544206.  ,  323101.  ,
#         734916.8 ], dtype=float32)

# %%
from sklearn.metrics import median_absolute_error
from sklearn.metrics import max_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics  import f1_score

print('MSE Score :',mean_squared_error(y_test1, predicted_label)) #Mean squared error(MSE)
print ('R2 Score :',r2_score(y_test1,predicted_label)) #R² score
print ('MAE Score :',mean_absolute_error(y_test1,predicted_label)) #Mean absolute error
#print('Explained Variance Score :',explained_variance_score(y_test, predicted_label)) #reject
print ('MedAE Score :',median_absolute_error(y_test1,predicted_label))#Median absolute error(MedAE)
# Out:
# MSE Score : 13539928881.442738
# R2 Score : 0.8881096839904785
# MAE Score : 69132.34884255301
# MedAE Score : 42490.265625

# %%
# Now predict a single value using an input with the same number of features
single_input = [[5,	2.50,	3000,	9050,	2.0,	0,	4,	5,	10,	3370,	280,	1921,	0,	52.8645,	-114.557,	2880,	5400,	2,	58]]  # Example input (replace with actual values)
single_prediction = regressor.predict(single_input)

print("Predicted value:", single_prediction)
# Out:
# Predicted value: [1816852.5]

# %%
# !pip install optuna

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import optuna

def objective(trial):
    params = {
        "objective": "reg:squarederror",
        "n_estimators": 1000,
        "verbosity": 0,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "max_depth": trial.suggest_int("max_depth", 1, 10),
        "subsample": trial.suggest_float("subsample", 0.05, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.05, 1.0),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 20),
    }

    model = xgb.XGBRegressor(**params)
    model.fit(x_train1, y_train1)
    predictions = model.predict(x_test1)
    r = r2_score(y_test1,  predictions)
    return r
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-329d3b2e4310> in <cell line: 3>()
#       1 import xgboost as xgb
#       2 from sklearn.metrics import mean_squared_error
# ----> 3 import optuna
#       4
#       5 def objective(trial):
#
# ModuleNotFoundError: No module named 'optuna'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=250)
# Out:
# [I 2024-11-26 12:35:59,409] A new study created in memory with name: no-name-c2ace418-d49b-4f85-9ddb-a4ba9e6ab3bd
# [I 2024-11-26 12:36:03,687] Trial 0 finished with value: 0.8680174946784973 and parameters: {'learning_rate': 0.004773399303668832, 'max_depth': 6, 'subsample': 0.28977947641483465, 'colsample_bytree': 0.430250835435054, 'min_child_weight': 11}. Best is trial 0 with value: 0.8680174946784973.
# [I 2024-11-26 12:36:04,639] Trial 1 finished with value: 0.788733720779419 and parameters: {'learning_rate': 0.0458814464916064, 'max_depth': 5, 'subsample': 0.6473414590055725, 'colsample_bytree': 0.05654014098990796, 'min_child_weight': 16}. Best is trial 0 with value: 0.8680174946784973.
# ...

# %%
print('Best hyperparameters :', study.best_params)
print('Best R2 :', study.best_value)
# Out:
# Best hyperparameters : {'learning_rate': 0.025564716142298008, 'max_depth': 7, 'subsample': 0.8610109893326394, 'colsample_bytree': 0.5362126004004085, 'min_child_weight': 3}
# Best R2 : 0.9154098033905029
